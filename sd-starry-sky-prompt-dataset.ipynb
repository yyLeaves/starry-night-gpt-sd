# %%
import os
import random

import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1c4WHxtlzvHYd0UY5WCMJNn2EO-Aiv2A0' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1c4WHxtlzvHYd0UY5WCMJNn2EO-Aiv2A0" -O openprompts.csv && rm /tmp/cookies.txt

# %%
prompts = pd.read_csv('/kaggle/input/openprompts/prompts.csv').drop('raw_data', axis = 1)
prompts = prompts.loc[prompts.prompt.str.split(' ').str.len() > 6]
prompts = prompts.reset_index(drop=True)
prompts
# Out:
#                                                     prompt
# 0        A portrait photo of a kangaroo wearing an oran...
# 1                 inmates with cow heads inside a jailcell
# 2        daguerrotype of a corgi astronaut on the moon,...
# 3        totem animal tribal chaman vodoo mask feather ...
# 4        Illustration of a sugar skull day of the dead ...
# ...                                                    ...
# 9637282  a curvilinear zaha hadid space-station city st...
# 9637283  pepe the frog on a throne in the style of Jan ...
# 9637284  photorealistic cgi portrait xena warrior princ...
# 9637285  a raccoon wearing formal clothes, wearing a to...
# 9637286  middle-aged witch, grinning, foxy, sharp featu...
#
# [9637287 rows x 1 columns]

# %%
list_prompts = [p for p in prompts['prompt'] if 'star' in p and 'sky' in p and 'night' in p]

# %%
for i in range(5):
    print(f"{i}")
    print(random.choice(list_prompts))
    print()
# Out:
# 0
# beautiful lush magic mana forest, night sky with dazzling stars, fairies, fireflies, bokeh, octane render, unreal engine, raytracing, crystallized, intricate, hyper detailed, light rays
#
# 1
# The collage features a woman with wings made of stars, surrounded by a blue and white night sky. The woman is holding a staff in one hand, and a star in the other. She is wearing a billowing white dress, and her hair is blowing in the wind. leather, kokedama by Mark Briscoe terrifying
#
# 2
# low angle wide shot, the elder scrolls vi hammerfell, capital city, marketsquare, mesa, oasis, sand dunes, ruined temple covered with moss, meadows, sub tropical, illustration, night time, starry sky, perfectly shaded, soft painting, art by krenz cushart and wenjun lin
#
# 3
# Gediminas_Pranckevicius a dramatic, epic, ethereal painting of shirtless Ari Shaffir dressed as clown with a beer belly wearing a large belt and bandana offering a balloon animal | he is relaxing by a campfire | background is a late night with food and jugs of whisky | stars, tarot card, art deco, art nouveau, mosaic, intricate | by Mark Maggiori | trending on artstation
#
# 4
# wide shot panorama 20mm lens of a nostalgic megalopolis skyline, at night, detailled, 8K, architecture photography, city, skyscrappers, starry sky, glass reflections, melancholy, lens flares, city lights, neons, raining, fog, silhouettes

# %%
with open('starry_night_prompts.txt', 'w') as f:
    f.write('\n\n'.join(list_prompts))
